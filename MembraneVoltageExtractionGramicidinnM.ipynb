# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.optimize import root_scalar

# %% [markdown]
# # Find membrane voltage using root finding in the GHK Flux equation
#
# 1. **GHK equation statement**:
#
# $\phi_{s} = P_{s} z_{s}^2\frac{V_m F^2}{RT} \frac{[S]_i - [S]_0 \exp(\frac{-z_sV_mF}{RT})}{1 - \exp(\frac{-z_sV_mF}{RT})}$
#
#
# 2. **We have the number flux density**:
#
# $J_{s} = -\frac{\phi_{s}}{z_sF}$
#
# **As our flux is defined as the rate of increase of the internal membrane concentration, we need a minus sign!**
#
# 3. **Solve the equation numerically**
#
# We know J and $[S]_i$ and $[S]_0$ and have extracted $P_s$ from the initial period of decay. All other parameters are constants. Therefore we can use this to find the membrane voltage by using a numerical root solver

# %%
F = 96485 #Cmol-1
z_s = 1
R = 8.31 #JK^-1mol^-1
T = 298 #K
C0 = 1 #mM or Molm^-3

# %%
# define flux equation for root solving

def flux_root(V,J,deltaC,P_s):
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction - J

def flux(V,deltaC,P_s):
    
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction

# %%
# determine mean J and then use this to determine average membrane voltage

deltaC_bins = np.linspace(0.5,1,20)

# %%
# load data

Js = pd.read_csv('Flux_GramA_3nM_20210920.csv')
deltaCs = pd.read_csv('deltaC_GramA_3nM_20210920.csv')
Ps = pd.read_csv('PbyGUVId_GramA_3nM_20210920.csv')

#clip away from initial period


Js = Js.iloc[:,1:]

deltaCs = deltaCs.iloc[:,1:]

# %%
Ps = Ps.iloc[:,1:]

# %%
V_mem = {}
V_mem_meta = {}
for key in Ps.keys():
    V_mem[key]= []
    V_mem_meta[key]= []

    for i,J in enumerate(Js[key]):

        print(key)
        deltaC = deltaCs[key].iloc[i]
        P = Ps[key].iloc[0]
        
        args = (J,deltaC,P)

        try:
            V = root_scalar(flux_root,args,method='brentq',bracket = [-1,1])
        except ValueError:
            continue
        print(V)
        V_mem[key].append(V.root)
        V_mem_meta[key].append(V)
        
        guess = V.root
# Out:
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.021255053692000436
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 13
#      iterations: 12
#            root: 0.0208111094192202
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.020592486045418627
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.020383701634708335
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.020184140705243155
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.019993226718563697
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.019810417748451162
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 13
#      iterations: 12
#            root: 0.019635202682570893
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.01946709786924212
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.01930564414977734
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.019150404220248555
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.01900096027747582
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 13
#      iterations: 12
#            root: 0.0188569119108165
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.01871787420702032
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.018583476041991155
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 13
#      iterations: 12
#            root: 0.01845335853234435
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.018327173631989855
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.01820458285160171
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.018085256088610342
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 12
#      iterations: 11
#            root: 0.01796887055450374
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.017855109787967616
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01774366274420317
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.017634222952932505
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.017526487736285956
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.017420157480837254
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 8
#      iterations: 7
#            root: 0.017281846368851682
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 9
#      iterations: 8
#            root: 0.017172296414429494
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.017115438598142397
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01704659417314394
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.016974625131594555
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.016928361336299578
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016882217743100003
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.016813981791368393
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01674818330454014
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016704409769976367
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016660479981863194
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01661515633370869
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01659986918456203
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016572386183290412
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01653128739023649
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016501870058930758
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016464325645110793
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016413586335318284
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016364226447233676
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016283701939952277
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016212903373940858
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016172502062353034
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016113705390086212
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01605733527682534
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.016006633118084652
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015941656055661772
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.01585915437341951
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015749345672493812
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015629940325886743
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015546187554148565
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015463217546653049
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015346891746002463
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015251215136625121
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015185771135230978
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015126331034859601
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.015061388501049027
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.014974115888324658
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.014894374814827941
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014808700583461072
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.014712869560543008
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.014629602700999651
# 03023
#       converged: True
#            flag: 'converged'
#  function_calls:
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014068090857031592
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01406181102570398
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014055529619748005
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014049246638668553
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014042962081973823
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014036675949176645
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01403038823978593
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014024098953307378
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014017808089255419
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014011515647138885
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.014005221626463253
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01399892602674466
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013992628847492953
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013986330088217713
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01398002974843252
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013973727827645267
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013967424325367185
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.01396111924111412
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013954812574397416
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.0139485043247276
# 05026
#       converged: True
#            flag: 'converged'
#  function_calls: 10
#      iterations: 9
#            root: 0.013942508082258272

# %%
Ps
# Out:
#    Unnamed: 0         11014         11019         11029         13012  \
# 0           0  2.325987e-09  4.540254e-09  9.552460e-09  1.045951e-09
#
#           13013         10033         10044         08005         08037  \
# 0  8.086907e-09  1.346878e-08  4.125428e-09  6.941839e-10  1.678880e-09
#
#           09001         09006         09008         09014
# 0  3.978354e-09  6.804831e-09  3.887612e-09  8.728744e-09

# %%
c = 0.5e-2 #F/m^2


C_guv = c*(4*np.pi*(1e-5)**2)

vol = ((4/3)*np.pi*(1e-5)**3)
Q = F*0.1*vol

V = Q/C_guv

# %%
V
# Out:
# 6.432333333333334

# %%
J_pred = {}
for key in V_mem.keys():
    V_1 = V_mem[key]
    P = Ps[key].iloc[0]
    deltaC = deltaCs[key]
    J_pred[key] = []
    for i,V in enumerate(V_1):

        deltaC_i = deltaC.iloc[i]

        J_pred[key].append(flux(V,deltaC_i,P))

# %%
# %matplotlib qt
dt = 9/60


threshold = 2

fig, axs = plt.subplots(1,3)
legend = []

for key in V_mem.keys():
    
    scaled_V = (F/(R*T))*np.array(V_mem[key])
#     if len(scaled_V[scaled_V> 2]) > 1:
# #         V_mem.pop(key)
#         continue
        
    if key in ['00005']:
        continue
    legend.append(key)
    axs[0].scatter(dt*np.arange(0,scaled_V.shape[0]),J_pred[key])
    axs[1].scatter(deltaCs[key],Js[key])
    
    
    axs[2].scatter(dt*np.arange(0,scaled_V.shape[0]),scaled_V)

axs[1].set_ylim([-0.1e-8,2e-8])
axs[0].set_ylim([-0.1e-8,2e-8])

axs[1].set_xlim([0,1.2])

plt.legend(legend)

# %% [markdown]
# # Find mean Flux and mean Membrane voltage

# %%
V_memdf = pd.DataFrame(V_mem)

# %%
Mean_V = (F/(R*T))*V_memdf.mean(axis = 1)
upper_V = (F/(R*T))*(V_memdf.mean(axis = 1)+V_memdf.std(axis = 1))
lower_V = (F/(R*T))*(V_memdf.mean(axis = 1)-V_memdf.std(axis = 1))
Mean_J = Js[V_memdf.columns].mean(axis = 1)
upper_J = Js[V_memdf.columns].mean(axis = 1)+Js[V_memdf.columns].std(axis = 1)
lower_J = Js[V_memdf.columns].mean(axis = 1)-Js[V_memdf.columns].std(axis = 1)

# %%
# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_V, marker = '+',s = 8)
ax.fill_between(t,lower_V,upper_V,alpha = 0.4)
# ax[1].scatter(dt*np.arange(Mean_V.shape[0]),Mean_J,marker = '+',s = 8)

# ax[1].set_ylim(-0.1e-8,1.1e-8)

plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)

y_ticks = [0,0.4,0.8]
x_ticks = [0,20,40]

ax.set_xticks(x_ticks)
ax.set_xticklabels(x_ticks,fontsize = 15)

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_ticks,fontsize = 15)

ax.set_xlabel( 'T [mins]',fontsize = 18)
ax.set_ylabel('V [(RT/F)V]',fontsize = 18)
# Out:
# Text(0, 0.5, 'V [(RT/F)V]')

# %%
def set_plot_params(ax,xticks,yticks,
                    xlabel,ylabel,x_sciformat = 1,y_sciformat = 1):
    plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)


    if x_sciformat != 1 or y_sciformat != 1:
        xticklabels = np.array(xticks)/x_sciformat
        yticklabels = np.array(yticks)/y_sciformat
        
    else:
        xticklabels = xticks
        yticklabels = yticks
        
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels,fontsize = 15)

    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels,fontsize = 15)

    ax.set_xlabel(xlabel,fontsize = 18)
    ax.set_ylabel(ylabel,fontsize = 18)

# %%
# make flux plot

# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_J, marker = '+',s = 8)
ax.fill_between(t,lower_J,upper_J,alpha = 0.4)

yticks = [0,0.5e-8,1e-8]
set_plot_params(ax,x_ticks,yticks,xlabel='Time [mins]',ylabel='Flux [$10^8 molm^{-2}s^{-1}$]',y_sciformat=1e-8)

ax.set_ylim(-0.1e-8,1.1e-8)
# Out:
# /home/marcus/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (-1e-09, 1.1e-08)

# %% [markdown]
# # Mean flux data

# %%
meanFluxdata = pd.read_csv('20210920_GramA3nM_MeanFluxvsdeltaC.csv')

# %%
V_mem = []
V_mem_meta = []
for i,J in enumerate(meanFluxdata['J']):

#         print(key)
        deltaC = meanFluxdata['deltaC'].iloc[i]
    
#         P = Ps[key].iloc[0]*0.8
        args = (J,deltaC,1)

        
        V = root_scalar(flux_root,args,method='brentq',bracket = [1e-18,10])
        print(V)
        V_mem.append(V.root)
        V_mem_meta.append(V)
        
        guess = V.root
# Out:
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.00880560226018403
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008821658493919072
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008950919259779373
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008477278576725894
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008412051648805074
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008561056035949517
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.014522102562674137
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.010735959262957114
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.009145632505602387
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008973595355490175
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.009374645116872346
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.009789529130747604
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.010335411175049098
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01090345671899805
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011530988634878917
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.012152628665880379
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.012432924332848663
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013039194356678881
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013481812686634042
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014061511127225616
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014485764642859878
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015142224831579105
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01503591367860631
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015367860816335854
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015615606743228188
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.0157420312704126
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015813963907364312
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01626002372773472
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016632195227966808
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016986627518255772
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.017353520878142004
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.017788947253420773
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.018089277603410017
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.018613513717898603
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.018889459086515417
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.019245202930048017
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.019433626499797785
# /home/marcus/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in double_scalars
#   if sys.path[0] == '':

# %%
fig, ax = plt.subplots(1,1)

ax.scatter((15/60)*np.arange(len(V_mem)),V_mem[::-1])
