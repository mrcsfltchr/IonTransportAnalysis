# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.optimize import root_scalar

# %% [markdown]
# # Find membrane voltage using root finding in the GHK Flux equation
#
# 1. **GHK equation statement**:
#
# $\phi_{s} = P_{s} z_{s}^2\frac{V_m F^2}{RT} \frac{[S]_i - [S]_0 \exp(\frac{-z_sV_mF}{RT})}{1 - \exp(\frac{-z_sV_mF}{RT})}$
#
#
# 2. **We have the number flux density**:
#
# $J_{s} = -\frac{\phi_{s}}{z_sF}$
#
# **As our flux is defined as the rate of increase of the internal membrane concentration, we need a minus sign!**
#
# 3. **Solve the equation numerically**
#
# We know J and $[S]_i$ and $[S]_0$ and have extracted $P_s$ from the initial period of decay. All other parameters are constants. Therefore we can use this to find the membrane voltage by using a numerical root solver

# %%
F = 96485 #Cmol-1
z_s = 1
R = 8.31 #JK^-1mol^-1
T = 298 #K
C0 = 1 #mM or Molm^-3

# %%
# define flux equation for root solving

def flux_root(V,J,deltaC,P_s):
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction - J

def flux(V,deltaC,P_s):
    
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction

# %%
# determine mean J and then use this to determine average membrane voltage

deltaC_bins = np.linspace(0.5,1,20)

# %%
# load data

Js = pd.read_csv('Flux_GramA_260pM_20210920.csv')
deltaCs = pd.read_csv('deltaC_GramA_260pM_20210920.csv')
Ps = pd.read_csv('PbyGUVId_GramA_260pM_20210920.csv')

#clip away from initial period


Js = Js.iloc[:,1:]

deltaCs = deltaCs.iloc[:,1:]

# %%
Ps = Ps.iloc[:,1:]

# %%
V_mem = {}
V_mem_meta = {}
for key in Ps.keys():
    V_mem[key]= []
    V_mem_meta[key]= []

    for i,J in enumerate(Js[key]):

        print(key)
        deltaC = deltaCs[key].iloc[i]
        P = Ps[key].iloc[0]
        args = (J,deltaC,P)

        try:
            V = root_scalar(flux_root,args,method='brentq',bracket = [-1,1])
        except ValueError:
            continue
        print(V)
        V_mem[key].append(V.root)
        V_mem_meta[key].append(V)
        
        guess = V.root
# Out:
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05740617364526152
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 14
#      iterations: 13
#            root: 0.057203121319457005
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.057002476106873964
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05680418225064075
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05660818596941784
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.056414435363440714
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.05622288032467083
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.056033472456507916
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.05584616499217955
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.05566091272245587
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05547767192557846
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05529640030139789
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05468719151120174
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05327899697423447
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05267948416003424
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05281772672109169
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.05392181439774861
# 11014
#       converged: True
#            flag: 'converged'
#  function_calls: 15
#      iterations: 14
#            root: 0.
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03399383368483164
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03394566967853723
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033902545613825906
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033823523507856744
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033759863064625126
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03374489988151693
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03373956539081267
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03373463804386683
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033733051203120056
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033715317301921954
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033675600555905065
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03363310395897721
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03358805998820731
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03352994487117596
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03345103890916381
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033377091657556375
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033340682688410034
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03330243805371155
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03328360712757434
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033274570599543925
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03326335567176969
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033293071970808504
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033291261141626366
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033229096886920315
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03319239990895007
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033197802027443934
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03320786997398619
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03320766462851641
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03319651278091269
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03316191333166539
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033125265548416265
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033081410371011165
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033049920637554096
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033037553125004546
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03300730707802649
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03298777794008153
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03297825843976424
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032983771500843084
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0330821362752833
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033179752810887725
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033201223764166
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033209486544255894
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03318086654926531
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033140510057284356
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03310038209300202
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03306011983711605
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03302533711129203
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03300394286711139
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03300514409499284
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.033009648919264785
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03299975593248116
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03300142606879858
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03299564876458571
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03298599762392608
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03301030110873092
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03302121232540715
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032987720334836226
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0329459561368174
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032904450077267076
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03286048830166851
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0328322041638475
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032825082060468566
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032821265216435004
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03282056267243439
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03283282450208735
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032839587377369306
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03282793064003441
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032806151275783284
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03278620330318906
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032768672033979054
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032753806304070925
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03271821286821277
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03264903330660269
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0325971970071472
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03257049804174989
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03254859529815724
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0325097960074844
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032467886684048354
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03244054041301567
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03241024882109185
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03240071880419135
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0323877205662637
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03237040101468531
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03235629480139764
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03233240227463717
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032308537977516844
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03228470179463134
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03226089361084931
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032237113311311884
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032213360781429404
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03218963590688168
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03216593857361636
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03214226866784602
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03211862607604741
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0320950106849592
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03207142238158204
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.032047861053175544
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03202432658725713
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03200081887160089
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.031977337794235276
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03195388324344314
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03193045510775862
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03190705327596633
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.0318836776370994
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03186032808043918
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03183700449551355
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03181370677209396
# 09014
#       converged: True
#            flag: 'converged'
#  function_calls: 11
#      iterations: 10
#            root: 0.03179028375100638

# %%
Ps
# Out:
#    Unnamed: 0         11014         11019         11029         13012  \
# 0           0  2.325987e-09  4.540254e-09  9.552460e-09  1.045951e-09
#
#           13013         10033         10044         08005         08037  \
# 0  8.086907e-09  1.346878e-08  4.125428e-09  6.941839e-10  1.678880e-09
#
#           09001         09006         09008         09014
# 0  3.978354e-09  6.804831e-09  3.887612e-09  8.728744e-09

# %%
c = 0.5e-2 #F/m^2


C_guv = c*(4*np.pi*(1e-5)**2)

vol = ((4/3)*np.pi*(1e-5)**3)
Q = F*0.1*vol

V = Q/C_guv

# %%
V
# Out:
# 6.432333333333334

# %%
J_pred = {}
for key in V_mem.keys():
    V_1 = V_mem[key]
    P = Ps[key].iloc[0]
    deltaC = deltaCs[key]
    J_pred[key] = []
    for i,V in enumerate(V_1):

        deltaC_i = deltaC.iloc[i]

        J_pred[key].append(flux(V,deltaC_i,P))

# %%
# %matplotlib qt
dt = 9/60


threshold = 2

fig, axs = plt.subplots(1,3)
legend = []

for key in V_mem.keys():
    
    scaled_V = (F/(R*T))*np.array(V_mem[key])
#     if len(scaled_V[scaled_V> 2]) > 1:
# #         V_mem.pop(key)
#         continue
        
    if key in ['13012']:
        continue
    legend.append(key)
    axs[0].scatter(dt*np.arange(0,scaled_V.shape[0]),J_pred[key])
    axs[1].scatter(deltaCs[key],Js[key])
    
    
    axs[2].scatter(dt*np.arange(0,scaled_V.shape[0]),scaled_V)

axs[1].set_ylim([-0.1e-8,2e-8])
axs[0].set_ylim([-0.1e-8,2e-8])

axs[1].set_xlim([0,1.2])

plt.legend(legend)

# %% [markdown]
# # Find mean Flux and mean Membrane voltage

# %%
V_memdf = pd.DataFrame(V_mem)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-22cbca0b140e> in <module>
# ----> 1 V_memdf = pd.DataFrame(V_mem)
#       2
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
Mean_V = (F/(R*T))*V_memdf.mean(axis = 1)
upper_V = (F/(R*T))*(V_memdf.mean(axis = 1)+V_memdf.std(axis = 1))
lower_V = (F/(R*T))*(V_memdf.mean(axis = 1)-V_memdf.std(axis = 1))
Mean_J = Js[V_memdf.columns].mean(axis = 1)
upper_J = Js[V_memdf.columns].mean(axis = 1)+Js[V_memdf.columns].std(axis = 1)
lower_J = Js[V_memdf.columns].mean(axis = 1)-Js[V_memdf.columns].std(axis = 1)

# %%
# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_V, marker = '+',s = 8)
ax.fill_between(t,lower_V,upper_V,alpha = 0.4)
# ax[1].scatter(dt*np.arange(Mean_V.shape[0]),Mean_J,marker = '+',s = 8)

# ax[1].set_ylim(-0.1e-8,1.1e-8)

plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)

y_ticks = [0,0.4,0.8]
x_ticks = [0,20,40]

ax.set_xticks(x_ticks)
ax.set_xticklabels(x_ticks,fontsize = 15)

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_ticks,fontsize = 15)

ax.set_xlabel( 'T [mins]',fontsize = 18)
ax.set_ylabel('V [(RT/F)V]',fontsize = 18)
# Out:
# Text(0, 0.5, 'V [(RT/F)V]')

# %%
def set_plot_params(ax,xticks,yticks,
                    xlabel,ylabel,x_sciformat = 1,y_sciformat = 1):
    plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)


    if x_sciformat != 1 or y_sciformat != 1:
        xticklabels = np.array(xticks)/x_sciformat
        yticklabels = np.array(yticks)/y_sciformat
        
    else:
        xticklabels = xticks
        yticklabels = yticks
        
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels,fontsize = 15)

    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels,fontsize = 15)

    ax.set_xlabel(xlabel,fontsize = 18)
    ax.set_ylabel(ylabel,fontsize = 18)

# %%
# make flux plot

# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_J, marker = '+',s = 8)
ax.fill_between(t,lower_J,upper_J,alpha = 0.4)

yticks = [0,0.5e-8,1e-8]
set_plot_params(ax,x_ticks,yticks,xlabel='Time [mins]',ylabel='Flux [$10^8 molm^{-2}s^{-1}$]',y_sciformat=1e-8)

ax.set_ylim(-0.1e-8,1.1e-8)
# Out:
# /home/marcus/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (-1e-09, 1.1e-08)
