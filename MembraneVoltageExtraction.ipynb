# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.optimize import root_scalar

# %% [markdown]
# # Find membrane voltage using root finding in the GHK Flux equation
#
# 1. **GHK equation statement**:
#
# $\phi_{s} = P_{s} z_{s}^2\frac{V_m F^2}{RT} \frac{[S]_i - [S]_0 \exp(\frac{-z_sV_mF}{RT})}{1 - \exp(\frac{-z_sV_mF}{RT})}$
#
#
# 2. **We have the number flux density**:
#
# $J_{s} = -\frac{\phi_{s}}{z_sF}$
#
# **As our flux is defined as the rate of increase of the internal membrane concentration, we need a minus sign!**
#
# 3. **Solve the equation numerically**
#
# We know J and $[S]_i$ and $[S]_0$ and have extracted $P_s$ from the initial period of decay. All other parameters are constants. Therefore we can use this to find the membrane voltage by using a numerical root solver

# %%
F = 96485 #Cmol-1
z_s = 1
R = 8.31 #JK^-1mol^-1
T = 298 #K
C0 = 1 #mM or Molm^-3

# %%
# define flux equation for root solving

def flux_root(V,J,deltaC,P_s):
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction - J

def flux(V,deltaC,P_s):
    
    
    F = 96485 #Cmol-1
    z_s = 1
    R = 8.31 #JK^-1mol^-1
    
    T = 298 #K
    C0 = 1 #mM or Molm^-3
    prefactor = -1*P_s*z_s*(V*F)/(R*T)
    
    fraction = (C0-deltaC - C0*np.exp((-z_s*V*F)/(R*T)))/(1-np.exp((-z_s*V*F)/(R*T)))
    
    return prefactor*fraction

# %%
# load data

Js = pd.read_csv('Flux_OmpF_20210427.csv')
deltaCs = pd.read_csv('deltaC_OmpF_20210427.csv')
Ps = pd.read_csv('PbyGUVId_OmpF_20210427.csv')

#clip away from initial period


Js = Js.iloc[:,1:]

deltaCs = deltaCs.iloc[:,1:]

# %%
V_mem = {}
V_mem_meta = {}
for key in Js.keys():
    V_mem[key]= []
    V_mem_meta[key]= []

    for i,J in enumerate(Js[key]):

        print(key)
        deltaC = deltaCs[key].iloc[i]
        P = Ps[key].iloc[0]*0.8
        args = (J,deltaC,P)

        
        V = root_scalar(flux_root,args,method='brentq',bracket = [1e-18,10])
        print(V)
        V_mem[key].append(V.root)
        V_mem_meta[key].append(V)
        
        guess = V.root
# Out:
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.005805926681607894
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.005320558301789266
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.0056138856305645865
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.005907641449325532
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.006197234005849466
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.006477791552409681
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.006744103234473257
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.006990560273530944
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.007211097108135466
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.008037435408763642
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.00906807320448202
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.009735438260364979
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.010570398522872606
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011377229888945161
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012092401573935868
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012860771374105007
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01350521462208619
# 04001
#       converged: True
#            flag: 'converged'
#  function_calls:
#  function_calls: 18
#      iterations: 17
#            root: 0.007196465710116209
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 19
#      iterations: 18
#            root: 0.008056929239161122
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.009053710865595862
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.0097671988712422
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.010566156422868131
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011108590496375331
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.011599937113845545
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012096036212399377
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012543042416568806
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012960214630010439
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013442917205269985
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014090564847877093
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014781071382061963
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01512348736839472
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01517379346024578
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015378203753239558
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01582615521126154
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016084886552816896
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013483724358476123
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011074016123516564
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011364752641083576
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.011719051540673688
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01197860375907993
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01213103611873817
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012423944408931398
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012716320275927088
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.012969393986443348
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013227816272680134
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013479060318190711
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.0136526270489564
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013819411525723826
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.013981288916235733
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014140085914933286
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014297574523884367
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014455466068993833
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.014615405497146372
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01477896599777759
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.0173799314996189
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.01990134537545034
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.019741167357120566
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.019579646979936895
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.019416740901730595
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.019252405711726855
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01908659793070537
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.018919274011480417
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01875039033969637
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.018579903234924488
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.018407768952054128
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01823394368197196
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.018058383557523615
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.017881044649716744
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.017701882974095095
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.017520854493019086
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.017337915118090703
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01715302071357397
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01696612709985163
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01677719005709542
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.01658616532913736
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016393008627535132
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016188167686222846
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.016009664885986194
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015833599701168315
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.01565123734285482
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015510309260130016
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015355910771967272
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.015195203756088235
# 04002
#       converged: True
#            flag: 'converged'
#  function_calls: 18
#      iterations: 17
#            root: 0.015024476382496283
# 04002
# ...
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.062015890505395965
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061925679419297795
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061805519286185856
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 16
#      iterations: 15
#            root: 0.061790116043925786
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06179895506575025
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06171777022483639
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06166026592931103
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06160166448271823
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06152859515873661
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06146070249430808
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061410900400583036
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06130647447139066
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06119544135773664
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06113154894259185
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061106297315376396
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0611228050765236
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06112223296849325
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06103946710001114
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06092617485492676
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06090666623861624
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060955858647425865
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06099014378273801
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060971353903681115
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060926198852060964
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06096550615617829
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06101957255656422
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06104699723883233
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06114965457953132
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061233266423563415
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06115403488638774
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06111847027868534
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06119649695846676
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06128266987483294
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061339919958523066
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06131932175609758
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061305874763828545
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06131344719588513
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061344742740032085
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06134175575348779
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061288378753208736
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061225253505462846
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.061152424104952564
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06114763927248194
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06105281784007988
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060897969633041456
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06082023520833334
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060773874201812315
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060769790306176526
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06078644717153768
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06075438187300808
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06065530074195597
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060531321203582275
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06047924470920019
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0604705169406924
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06039656136450233
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06034339169729728
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060302033367300154
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060292559463647234
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06032753728322996
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06031879651709717
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060272898194537135
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06021938575375495
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.060188003769049356
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06015013782523864
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.06005707588372233
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059953792483381195
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05983397202288105
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059743912546493146
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059731675262392654
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059723134933987766
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05967363107502369
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05956973048964198
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05947792452779512
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059415519822683616
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05935072659093714
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059275006073376865
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059158512272214255
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.059011201186808464
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05893079627672506
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.058894552526197665
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05882205648372142
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0587791452555329
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0587857888675063
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05881378361036194
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05878664686441085
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05873010811376885
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05869900726512704
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05863502331495935
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05856729055807044
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05851658615195785
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.058466001326976894
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.058415535566253445
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.058365188356245594
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0583149591867173
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05826484755070578
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05821485294449523
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05816497486759185
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05811521282269268
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05806556631565985
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05801603485549303
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05796661795430554
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057917315127295185
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057868125892715234
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057819049771856486
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.0577700862890167
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05772123497147464
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057672495349468174
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05762386695616857
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05757534932765431
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05752694200288646
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05747864452369006
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05743045643472559
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057382377283463876
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05733440662016854
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.057286543997869165
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05723878897233928
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05719114110207474
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05714359994827033
# 14013
#       converged: True
#            flag: 'converged'
#  function_calls: 17
#      iterations: 16
#            root: 0.05709606355555331

# %%
c = 0.5e-2 #F/m^2


C_guv = c*(4*np.pi*(1e-5)**2)

vol = ((4/3)*np.pi*(1e-5)**3)
Q = F*0.1*vol

V = Q/C_guv

# %%
V
# Out:
# 6.432333333333334

# %%
J_pred = {}
for key in V_mem.keys():
    V_1 = V_mem[key]
    P = Ps[key].iloc[0]
    deltaC = deltaCs[key]
    J_pred[key] = []
    for i,V in enumerate(V_1):

        deltaC_i = deltaC.iloc[i]

        J_pred[key].append(flux(V,deltaC_i,P))

# %%
# %matplotlib qt
dt = 9/60


threshold = 2

fig, axs = plt.subplots(1,3)

for key in Js.keys():
    
    scaled_V = (F/(R*T))*np.array(V_mem[key])
    if len(scaled_V[scaled_V> 2]) > 1:
        V_mem.pop(key)
        continue
        
    axs[0].scatter(dt*np.arange(0,scaled_V.shape[0]),J_pred[key])
    axs[1].scatter(deltaCs[key],Js[key])
    
    
    axs[2].scatter(dt*np.arange(0,scaled_V.shape[0]),scaled_V)

axs[1].set_ylim([-0.1e-8,2e-8])
axs[0].set_ylim([-0.1e-8,2e-8])

axs[1].set_xlim([0,1.2])
# Out:
# (0, 1.2)

# %% [markdown]
# # Find mean Flux and mean Membrane voltage

# %%
V_memdf = pd.DataFrame(V_mem)

# %%
Mean_V = (F/(R*T))*V_memdf.mean(axis = 1)
upper_V = (F/(R*T))*(V_memdf.mean(axis = 1)+V_memdf.std(axis = 1))
lower_V = (F/(R*T))*(V_memdf.mean(axis = 1)-V_memdf.std(axis = 1))
Mean_J = Js[V_memdf.columns].mean(axis = 1)
upper_J = Js[V_memdf.columns].mean(axis = 1)+Js[V_memdf.columns].std(axis = 1)
lower_J = Js[V_memdf.columns].mean(axis = 1)-Js[V_memdf.columns].std(axis = 1)

# %%
# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_V, marker = '+',s = 8)
ax.fill_between(t,lower_V,upper_V,alpha = 0.4)
# ax[1].scatter(dt*np.arange(Mean_V.shape[0]),Mean_J,marker = '+',s = 8)

# ax[1].set_ylim(-0.1e-8,1.1e-8)

plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)

y_ticks = [0,0.4,0.8]
x_ticks = [0,20,40]

ax.set_xticks(x_ticks)
ax.set_xticklabels(x_ticks,fontsize = 15)

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_ticks,fontsize = 15)

ax.set_xlabel( 'T [mins]',fontsize = 18)
ax.set_ylabel('V [(RT/F)V]',fontsize = 18)
# Out:
# Text(0, 0.5, 'V [(RT/F)V]')

# %%
def set_plot_params(ax,xticks,yticks,
                    xlabel,ylabel,x_sciformat = 1,y_sciformat = 1):
    plt.tick_params(direction = 'in',top = True,right = True,left = True,bottom = True, length = 6)


    if x_sciformat != 1 or y_sciformat != 1:
        xticklabels = np.array(xticks)/x_sciformat
        yticklabels = np.array(yticks)/y_sciformat
        
    else:
        xticklabels = xticks
        yticklabels = yticks
        
    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels,fontsize = 15)

    ax.set_yticks(yticks)
    ax.set_yticklabels(yticklabels,fontsize = 15)

    ax.set_xlabel(xlabel,fontsize = 18)
    ax.set_ylabel(ylabel,fontsize = 18)

# %%
# make flux plot

# plot mean membrane voltage

fig, ax = plt.subplots(1,1)

t = dt*np.arange(Mean_V.shape[0]) #mins

ax.scatter(t,Mean_J, marker = '+',s = 8)
ax.fill_between(t,lower_J,upper_J,alpha = 0.4)

yticks = [0,0.5e-8,1e-8]
set_plot_params(ax,x_ticks,yticks,xlabel='Time [mins]',ylabel='Flux [$10^8 molm^{-2}s^{-1}$]',y_sciformat=1e-8)

ax.set_ylim(-0.1e-8,1.1e-8)
# Out:
# /home/marcus/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# (-1e-09, 1.1e-08)
